# %% [markdown]
# <a href="https://colab.research.google.com/github/kwokrico/GoogleCollab/blob/main/Hassell_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PIP INSTALL

# %%
# Install the required library here
# !pip install docx2pdf
# !pip install keyboard
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 887.0 kB/s eta 0:00:00
# ...

# %% [markdown]
# # IMPORT

# %%
import os
import shutil
import datetime

# %%
from func_OS import OSManager

# %%
os_manager = OSManager()

# %% [markdown]
# # DIR CREATE

# %%
DIR_TO_BE_CREATED = [
    "DOCX_to_PDF",
]

# %%
for dir in DIR_TO_BE_CREATED:
  os_manager.check_directory(directory_path = dir)
# Out:
# The directory 'DOCX_to_PDF' already exists.
# ----------------------------------------------------

# %% [markdown]
# # VAR

# %%
current_date = os_manager.get_current_date()

# %% [markdown]
# # FUNC

# %% [markdown]
# # MAIN

# %%
# Out:
# The directory 'DOCX_to_PDF' already exists.
# ----------------------------------------------------
# True

# %%
# Out:
# datetime.date(2024, 7, 18)
